# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel("D:\\Avinash\\Machine Learning\\Global Superstore.xls","Orders")

# %%
df
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891 2012-07-31 2012-07-31        Same Day
# 1       26341    IN-2013-77878 2013-02-05 2013-02-07    Second Class
# 2       25330    IN-2013-71249 2013-10-17 2013-10-18     First Class
# 3       13524  ES-2013-1579342 2013-01-28 2013-01-30     First Class
# 4       47221     SG-2013-4320 2013-11-05 2013-11-06        Same Day
# ...       ...              ...        ...        ...             ...
# 51285   29002    IN-2014-62366 2014-06-19 2014-06-19        Same Day
# 51286   35398   US-2014-102288 2014-06-20 2014-06-24  Standard Class
# 51287   40470   US-2013-155768 2013-12-02 2013-12-02        Same Day
# 51288    9596   MX-2012-140767 2012-02-18 2012-02-22  Standard Class
# 51289    6147   MX-2012-134460 2012-05-22 2012-05-26    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# 0        RH-19495       Rick Hansen     Consumer  New York City
# 1        JR-16210     Justin Ritter    Corporate     Wollongong
# 2        CR-12730      Craig Reiter     Consumer       Brisbane
# 3        KM-16375  Katherine Murray  Home Office         Berlin
# 4         RH-9495       Rick Hansen     Consumer          Dakar
# ...           ...               ...          ...            ...
# 51285    KE-16420   Katrina Edelman    Corporate           Kure
# 51286    ZC-21910  Zuschuss Carroll     Consumer        Houston
# 51287    LB-16795    Laurel Beltran  Home Office         Oxnard
# 51288    RB-19795        Ross Baird  Home Office       Valinhos
# 51289    MC-18100     Mick Crebagga     Consumer       Tipitapa
#
#                  State  ...        Product ID         Category Sub-Category  \
# 0             New York  ...   TEC-AC-10003033       Technology  Accessories
# 1      New South Wales  ...   FUR-CH-10003950        Furniture       Chairs
# 2           Queensland  ...   TEC-PH-10004664       Technology       Phones
# 3               Berlin  ...   TEC-PH-10004583       Technology       Phones
# 4                Dakar  ...  TEC-SHA-10000501       Technology      Copiers
# ...                ...  ...               ...              ...          ...
# 51285        Hiroshima  ...   OFF-FA-10000746  Office Supplies    Fasteners
# 51286            Texas  ...   OFF-AP-10002906  Office Supplies   Appliances
# 51287       California  ...   OFF-EN-10001219  Office Supplies    Envelopes
# 51288        São Paulo  ...   OFF-BI-10000806  Office Supplies      Binders
# 51289          Managua  ...   OFF-PA-10004155  Office Supplies        Paper
#
#                                             Product Name     Sales Quantity  \
# 0      Plantronics CS510 - Over-the-Head monaural Wir...  2309.650        7
# 1              Novimex Executive Leather Armchair, Black  3709.395        9
# 2                      Nokia Smart Phone, with Caller ID  5175.171        9
# 3                         Motorola Smart Phone, Cordless  2892.510        5
# 4                         Sharp Wireless Fax, High-Speed  2832.960        8
# ...                                                  ...       ...      ...
# 51285                      Advantus Thumb Tacks, 12 Pack    65.100        5
# 51286  Hoover Replacement Belt for Commercial Guardsm...     0.444        1
# 51287       #10- 4 1/8" x 9 1/2" Security-Tint Envelopes    22.920        3
# 51288                            Acco Index Tab, Economy    13.440        2
# 51289            Eaton Computer Printout Paper, 8.5 x 11    61.380        3
#
#       Discount    Profit  Shipping Cost  Order Priority
# 0          0.0  762.1845        933.570        Critical
# 1          0.1 -288.7650        923.630        Critical
# 2          0.1  919.9710        915.490          Medium
# 3          0.1  -96.5400        910.160          Medium
# 4          0.0  311.5200        903.040        Critical
# ...        ...       ...            ...             ...
# 51285      0.0    4.5000          0.010          Medium
# 51286      0.8   -1.1100          0.010          Medium
# 51287      0.0   11.2308          0.010            High
# 51288      0.0    2.4000          0.003          Medium
# 51289      0.0    1.8000          0.002            High
#
# [51290 rows x 24 columns]

# %%
df.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# City                      object
# State                     object
# Country                   object
# Postal Code              float64
# Market                    object
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority            object
# dtype: object

# %%
df.shape
# Out:
# (51290, 24)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
df.isnull()
# Out:
#        Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0       False     False       False      False      False        False
# 1       False     False       False      False      False        False
# 2       False     False       False      False      False        False
# 3       False     False       False      False      False        False
# 4       False     False       False      False      False        False
# ...       ...       ...         ...        ...        ...          ...
# 51285   False     False       False      False      False        False
# 51286   False     False       False      False      False        False
# 51287   False     False       False      False      False        False
# 51288   False     False       False      False      False        False
# 51289   False     False       False      False      False        False
#
#        Customer Name  Segment   City  State  ...  Product ID  Category  \
# 0              False    False  False  False  ...       False     False
# 1              False    False  False  False  ...       False     False
# 2              False    False  False  False  ...       False     False
# 3              False    False  False  False  ...       False     False
# 4              False    False  False  False  ...       False     False
# ...              ...      ...    ...    ...  ...         ...       ...
# 51285          False    False  False  False  ...       False     False
# 51286          False    False  False  False  ...       False     False
# 51287          False    False  False  False  ...       False     False
# 51288          False    False  False  False  ...       False     False
# 51289          False    False  False  False  ...       False     False
#
#        Sub-Category  Product Name  Sales  Quantity  Discount  Profit  \
# 0             False         False  False     False     False   False
# 1             False         False  False     False     False   False
# 2             False         False  False     False     False   False
# 3             False         False  False     False     False   False
# 4             False         False  False     False     False   False
# ...             ...           ...    ...       ...       ...     ...
# 51285         False         False  False     False     False   False
# 51286         False         False  False     False     False   False
# 51287         False         False  False     False     False   False
# 51288         False         False  False     False     False   False
# 51289         False         False  False     False     False   False
#
#        Shipping Cost  Order Priority
# 0              False           False
# 1              False           False
# 2              False           False
# 3              False           False
# 4              False           False
# ...              ...             ...
# 51285          False           False
# 51286          False           False
# 51287          False           False
# 51288          False           False
# 51289          False           False
#
# [51290 rows x 24 columns]

# %%
df.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Postal Code       41296
# Market                0
# Region                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
df.describe()
# Out:
#             Row ID                     Order Date  \
# count  51290.00000                          51290
# mean   25645.50000  2013-05-11 21:26:49.155781120
# min        1.00000            2011-01-01 00:00:00
# 25%    12823.25000            2012-06-19 00:00:00
# 50%    25645.50000            2013-07-08 00:00:00
# 75%    38467.75000            2014-05-22 00:00:00
# max    51290.00000            2014-12-31 00:00:00
# std    14806.29199                            NaN
#
#                            Ship Date   Postal Code         Sales  \
# count                          51290   9994.000000  51290.000000
# mean   2013-05-15 20:42:42.745174528  55190.379428    246.490581
# min              2011-01-03 00:00:00   1040.000000      0.444000
# 25%              2012-06-23 00:00:00  23223.000000     30.758625
# 50%              2013-07-12 00:00:00  56430.500000     85.053000
# 75%              2014-05-26 00:00:00  90008.000000    251.053200
# max              2015-01-07 00:00:00  99301.000000  22638.480000
# std                              NaN  32063.693350    487.565361
#
#            Quantity      Discount        Profit  Shipping Cost
# count  51290.000000  51290.000000  51290.000000   51290.000000
# mean       3.476545      0.142908     28.610982      26.375818
# min        1.000000      0.000000  -6599.978000       0.002000
# 25%        2.000000      0.000000      0.000000       2.610000
# 50%        3.000000      0.000000      9.240000       7.790000
# 75%        5.000000      0.200000     36.810000      24.450000
# max       14.000000      0.850000   8399.976000     933.570000
# std        2.278766      0.212280    174.340972      57.296810

# %%
from matplotlib import pyplot as plt
from matplotlib import style
import seaborn as sbn
# %matplotlib inline

# %%
plt.boxplot(df["Profit"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a94572cda0>,
#   <matplotlib.lines.Line2D at 0x1a94572d0d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1a94572d3d0>,
#   <matplotlib.lines.Line2D at 0x1a94572d700>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1a94572cb30>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a94572da30>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a94572dd60>],
#  'means': []}

# %%
df["Profit"].quantile([0.1,0.25,0.5,0.75,1.0])
# Out:
# 0.10     -30.5712
# 0.25       0.0000
# 0.50       9.2400
# 0.75      36.8100
# 1.00    8399.9760
# Name: Profit, dtype: float64

# %%
df.shape
# Out:
# (51290, 24)

# %%
df_1=df[(df["Profit"] >=0.0) & (df["Profit"] <=36.8100)]

# %%
df_1.shape
# Out:
# (25928, 24)

# %%
plt.boxplot(df_1["Profit"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a9457d9a30>,
#   <matplotlib.lines.Line2D at 0x1a9457d9d60>],
#  'caps': [<matplotlib.lines.Line2D at 0x1a9457da030>,
#   <matplotlib.lines.Line2D at 0x1a9457da300>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1a9457d9760>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a9457da600>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a9457da8a0>],
#  'means': []}

# %%
plt.boxplot(df_1["Sales"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a945845f40>,
#   <matplotlib.lines.Line2D at 0x1a9458461b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1a945846480>,
#   <matplotlib.lines.Line2D at 0x1a945846720>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1a945845c70>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a945846a50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a945846cc0>],
#  'means': []}

# %%
df_1["Sales"].quantile([0.1,0.25,0.5,0.75,1.0])
# Out:
# 0.10      12.54
# 0.25      23.64
# 0.50      48.78
# 0.75      96.18
# 1.00    3616.50
# Name: Sales, dtype: float64

# %%
df_1.shape
# Out:
# (25928, 24)

# %%
df_2=df_1[(df_1["Sales"] >=23.64) & (df_1["Sales"] <=96.18)]

# %%
df_2.shape
# Out:
# (12977, 24)

# %%
plt.boxplot(df_2["Sales"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a9458ba240>,
#   <matplotlib.lines.Line2D at 0x1a9458ba540>],
#  'caps': [<matplotlib.lines.Line2D at 0x1a9458ba7b0>,
#   <matplotlib.lines.Line2D at 0x1a9458baa50>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1a9458ba000>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a9458bad50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a9458bb020>],
#  'means': []}

# %%
plt.boxplot(df_2["Quantity"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a945c2d520>,
#   <matplotlib.lines.Line2D at 0x1a945c2d7f0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1a94581e930>,
#   <matplotlib.lines.Line2D at 0x1a945c2dca0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1a945c2d220>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a945c2dfa0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a945c2e2d0>],
#  'means': []}

# %%
df_2["Quantity"].quantile([0.1,0.25,0.5,0.75,1.0])
# Out:
# 0.10     1.0
# 0.25     2.0
# 0.50     3.0
# 0.75     4.0
# 1.00    14.0
# Name: Quantity, dtype: float64

# %%
df_3=df_2[(df_2["Quantity"]>=2.0)&(df_2["Quantity"]<=4.0)]

# %%
df_2.shape
# Out:
# (12977, 24)

# %%
df_3.shape
# Out:
# (7906, 24)

# %%
plt.boxplot(df_3["Quantity"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a945c73b90>,
#   <matplotlib.lines.Line2D at 0x1a945c73ec0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1a945cb41d0>,
#   <matplotlib.lines.Line2D at 0x1a945cb44d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1a945c73860>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a945cb47a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a945cb4a40>],
#  'means': []}

# %%
plt.boxplot(df_3["Shipping Cost"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a945efb8f0>,
#   <matplotlib.lines.Line2D at 0x1a945efbad0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1a945efbe00>,
#   <matplotlib.lines.Line2D at 0x1a945f240b0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1a945efb620>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a945f24350>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a945f24590>],
#  'means': []}

# %%
df_3["Shipping Cost"].quantile([0.1,0.25,0.5,0.75,1.0])
# Out:
# 0.10     1.72000
# 0.25     2.70000
# 0.50     4.46100
# 0.75     7.23675
# 1.00    47.28000
# Name: Shipping Cost, dtype: float64

# %%
df_4=df_3[(df_3["Shipping Cost"]>=2.70)&(df_3["Shipping Cost"]<=7.23675)]

# %%
df_3.shape
# Out:
# (7906, 24)

# %%
df_4.shape
# Out:
# (3953, 24)

# %%
plt.boxplot(df_4["Shipping Cost"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a945cb5a00>,
#   <matplotlib.lines.Line2D at 0x1a945f661b0>],
#  'caps': [<matplotlib.lines.Line2D at 0x1a945f66480>,
#   <matplotlib.lines.Line2D at 0x1a945f66720>],
#  'boxes': [<matplotlib.lines.Line2D at 0x1a945f25e80>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a945f669f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a945f66cf0>],
#  'means': []}

# %%
df_4.head()
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 26583   10778  ES-2014-5617990 2014-09-11 2014-09-12     First Class
# 26584   17129  ES-2014-3096832 2014-07-04 2014-07-09  Standard Class
# 26586   21231    IN-2012-45951 2012-11-02 2012-11-06  Standard Class
# 26587   23945    IN-2012-40547 2012-11-29 2012-11-30     First Class
# 26594   31408   CA-2013-128867 2013-11-04 2013-11-11  Standard Class
#
#       Customer ID   Customer Name    Segment          City            State  \
# 26583    LW-16825  Laurel Workman  Corporate  Schiltigheim           Alsace
# 26584    BW-11065   Barry Weirich   Consumer       Catania           Sicily
# 26586    JG-15115      Jack Garza   Consumer        Bhopal   Madhya Pradesh
# 26587    GT-14710       Greg Tran   Consumer      Adelaide  South Australia
# 26594    CL-12565     Clay Ludtke   Consumer     Urbandale             Iowa
#
#        ...       Product ID         Category Sub-Category  \
# 26583  ...  OFF-SU-10003160  Office Supplies     Supplies
# 26584  ...  OFF-AR-10002145  Office Supplies          Art
# 26586  ...  OFF-EN-10000315  Office Supplies    Envelopes
# 26587  ...  OFF-BI-10004685  Office Supplies      Binders
# 26594  ...  OFF-AR-10000380  Office Supplies          Art
#
#                                           Product Name   Sales Quantity  \
# 26583                           Acme Ruler, High Speed  33.420        2
# 26584           Binney & Smith Sketch Pad, Fluorescent  95.160        2
# 26586          Jiffy Business Envelopes, Security-Tint  47.880        3
# 26587                             Acco Binder, Economy  40.905        3
# 26594  Hunt PowerHouse Electric Pencil Sharpener, Blue  75.960        2
#
#       Discount  Profit  Shipping Cost  Order Priority
# 26583      0.0   1.320           7.23            High
# 26584      0.0   4.740           7.23          Medium
# 26586      0.0   9.090           7.23            High
# 26587      0.1   9.495           7.23            High
# 26594      0.0  22.788           7.23          Medium
#
# [5 rows x 24 columns]

# %%
#Missing Values Imputations

# %%
df_4.isnull().sum()
# Out:
# Row ID               0
# Order ID             0
# Order Date           0
# Ship Date            0
# Ship Mode            0
# Customer ID          0
# Customer Name        0
# Segment              0
# City                 0
# State                0
# Country              0
# Postal Code       3268
# Market               0
# Region               0
# Product ID           0
# Category             0
# Sub-Category         0
# Product Name         0
# Sales                0
# Quantity             0
# Discount             0
# Profit               0
# Shipping Cost        0
# Order Priority       0
# dtype: int64

# %%
df_4.drop(["Postal Code"],axis=1,inplace=True)
# Out:
# C:\Users\purna\AppData\Local\Temp\ipykernel_15152\3596599742.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_4.drop(["Postal Code"],axis=1,inplace=True)

# %%
df_4.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# City              0
# State             0
# Country           0
# Market            0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# Shipping Cost     0
# Order Priority    0
# dtype: int64

# %%
df4_num=df_4.select_dtypes(include=[np.number])

# %%
df4_num
# Out:
#        Row ID   Sales  Quantity  Discount   Profit  Shipping Cost
# 26583   10778  33.420         2       0.0   1.3200           7.23
# 26584   17129  95.160         2       0.0   4.7400           7.23
# 26586   21231  47.880         3       0.0   9.0900           7.23
# 26587   23945  40.905         3       0.1   9.4950           7.23
# 26594   31408  75.960         2       0.0  22.7880           7.23
# ...       ...     ...       ...       ...      ...            ...
# 38117   16829  49.380         2       0.0   3.9000           2.70
# 38120   21176  47.844         4       0.1  21.2040           2.70
# 38127   30914  30.660         2       0.0   8.8800           2.70
# 38128   32008  24.448         4       0.2   8.8624           2.70
# 38136   50407  35.760         2       0.0  12.1200           2.70
#
# [3953 rows x 6 columns]

# %%
df4_cate=df_4.select_dtypes(include=["object"])

# %%
df4_cate
# Out:
#               Order ID       Ship Mode Customer ID      Customer Name  \
# 26583  ES-2014-5617990     First Class    LW-16825     Laurel Workman
# 26584  ES-2014-3096832  Standard Class    BW-11065      Barry Weirich
# 26586    IN-2012-45951  Standard Class    JG-15115         Jack Garza
# 26587    IN-2012-40547     First Class    GT-14710          Greg Tran
# 26594   CA-2013-128867  Standard Class    CL-12565        Clay Ludtke
# ...                ...             ...         ...                ...
# 38117  ES-2013-1469005    Second Class    MC-17635     Matthew Clasen
# 38120    IN-2014-23621  Standard Class    GR-14560  Georgia Rosenberg
# 38127    IN-2013-80594  Standard Class    KA-16525     Kelly Andreada
# 38128   CA-2014-146136  Standard Class    AP-10915     Arthur Prichep
# 38136      IZ-2011-890  Standard Class     KC-6675    Kimberly Carter
#
#          Segment          City            State        Country Market  \
# 26583  Corporate  Schiltigheim           Alsace         France     EU
# 26584   Consumer       Catania           Sicily          Italy     EU
# 26586   Consumer        Bhopal   Madhya Pradesh          India   APAC
# 26587   Consumer      Adelaide  South Australia      Australia   APAC
# 26594   Consumer     Urbandale             Iowa  United States     US
# ...          ...           ...              ...            ...    ...
# 38117  Corporate        Modena   Emilia-Romagna          Italy     EU
# 38120  Corporate     Melbourne         Victoria      Australia   APAC
# 38127   Consumer  Christchurch       Canterbury    New Zealand   APAC
# 38128   Consumer    Palm Coast          Florida  United States     US
# 38136  Corporate         Mosul           Ninawa           Iraq   EMEA
#
#              Region        Product ID         Category Sub-Category  \
# 26583       Central   OFF-SU-10003160  Office Supplies     Supplies
# 26584         South   OFF-AR-10002145  Office Supplies          Art
# 26586  Central Asia   OFF-EN-10000315  Office Supplies    Envelopes
# 26587       Oceania   OFF-BI-10004685  Office Supplies      Binders
# 26594       Central   OFF-AR-10000380  Office Supplies          Art
# ...             ...               ...              ...          ...
# 38117         South   OFF-EN-10004051  Office Supplies    Envelopes
# 38120       Oceania   OFF-BI-10004553  Office Supplies      Binders
# 38127       Oceania   OFF-BI-10004185  Office Supplies      Binders
# 38128         South   OFF-EN-10001219  Office Supplies    Envelopes
# 38136          EMEA  OFF-STA-10001791  Office Supplies          Art
#
#                                           Product Name Order Priority
# 26583                           Acme Ruler, High Speed           High
# 26584           Binney & Smith Sketch Pad, Fluorescent         Medium
# 26586          Jiffy Business Envelopes, Security-Tint           High
# 26587                             Acco Binder, Economy           High
# 26594  Hunt PowerHouse Electric Pencil Sharpener, Blue         Medium
# ...                                                ...            ...
# 38117                  Ames Manila Envelope, Set of 50         Medium
# 38120                           Cardinal Binder, Clear         Medium
# 38127                         Cardinal Binder, Durable         Medium
# 38128     #10- 4 1/8" x 9 1/2" Security-Tint Envelopes           High
# 38136                Stanley Highlighters, Water Color         Medium
#
# [3953 rows x 15 columns]

# %%
df4_num.columns
# Out:
# Index(['Row ID', 'Sales', 'Quantity', 'Discount', 'Profit', 'Shipping Cost'], dtype='object')

# %%
df4_cate.columns
# Out:
# Index(['Order ID', 'Ship Mode', 'Customer ID', 'Customer Name', 'Segment',
#        'City', 'State', 'Country', 'Market', 'Region', 'Product ID',
#        'Category', 'Sub-Category', 'Product Name', 'Order Priority'],
#       dtype='object')

# %%
#Encoding and Scaling

# %%
df4_num.drop(['Row ID'],axis=1,inplace=True)

# %%
from sklearn import preprocessing

# %%
le=preprocessing.LabelEncoder()

# %%
mm_scaler = preprocessing.MinMaxScaler()

# %%
df4_cat_e=df4_cate.apply(le.fit_transform)

# %%
df4_num.columns
# Out:
# Index(['Sales', 'Quantity', 'Discount', 'Profit', 'Shipping Cost'], dtype='object')

# %%
df4_num_mm =mm_scaler.fit_transform(df4_num)

# %%
df4_num_mm_sc=pd.DataFrame(df4_num_mm)

# %%
df4_num_mm_sc.head()
# Out:
#           0    1    2         3    4
# 0  0.134822  0.0  0.0  0.035948  1.0
# 1  0.985939  0.0  0.0  0.129085  1.0
# 2  0.334160  0.5  0.0  0.247549  1.0
# 3  0.238007  0.5  0.2  0.258578  1.0
# 4  0.721257  0.0  0.0  0.620588  1.0

# %%
df4_cat_e.head()
# Out:
#        Order ID  Ship Mode  Customer ID  Customer Name  Segment  City  State  \
# 26583      1476          0          706            447        1  1229     19
# 26584      1359          3          183             70        0   282    497
# 26586      1773          3          544            337        0   176    319
# 26587      1758          0          468            310        0    10    506
# 26594       353          3          232            169        0  1390    246
#
#        Country  Market  Region  Product ID  Category  Sub-Category  \
# 26583       35       4       3        2160         1            14
# 26584       51       4      10         462         1             2
# 26586       46       0       4         923         1             6
# 26587        4       0       9         826         1             3
# 26594      105       6       3         352         1             2
#
#        Product Name  Order Priority
# 26583            79               1
# 26584           271               3
# 26586           739               1
# 26587            27               1
# 26594           697               3

# %%
d1=df4_cat_e.reset_index()

# %%
d1.head()
# Out:
#    index  Order ID  Ship Mode  Customer ID  Customer Name  Segment  City  \
# 0  26583      1476          0          706            447        1  1229
# 1  26584      1359          3          183             70        0   282
# 2  26586      1773          3          544            337        0   176
# 3  26587      1758          0          468            310        0    10
# 4  26594       353          3          232            169        0  1390
#
#    State  Country  Market  Region  Product ID  Category  Sub-Category  \
# 0     19       35       4       3        2160         1            14
# 1    497       51       4      10         462         1             2
# 2    319       46       0       4         923         1             6
# 3    506        4       0       9         826         1             3
# 4    246      105       6       3         352         1             2
#
#    Product Name  Order Priority
# 0            79               1
# 1           271               3
# 2           739               1
# 3            27               1
# 4           697               3

# %%
d1.drop(["index"],axis=1,inplace=True)

# %%
df_final=pd.concat([df4_num_mm_sc,d1],axis=1)

# %%
df_final
# Out:
#              0    1    2         3    4  Order ID  Ship Mode  Customer ID  \
# 0     0.134822  0.0  0.0  0.035948  1.0      1476          0          706
# 1     0.985939  0.0  0.0  0.129085  1.0      1359          3          183
# 2     0.334160  0.5  0.0  0.247549  1.0      1773          3          544
# 3     0.238007  0.5  0.2  0.258578  1.0      1758          0          468
# 4     0.721257  0.0  0.0  0.620588  1.0       353          3          232
# ...        ...  ...  ...       ...  ...       ...        ...          ...
# 3948  0.354839  0.0  0.0  0.106209  0.0      1043          2          722
# 3949  0.333664  1.0  0.2  0.577451  0.0      2068          3          466
# 3950  0.096774  0.0  0.0  0.241830  0.0      2008          3          614
# 3951  0.011139  1.0  0.4  0.241351  0.0       560          3           67
# 3952  0.167080  0.0  0.0  0.330065  0.0      2396          3          627
#
#       Customer Name  Segment  City  State  Country  Market  Region  \
# 0               447        1  1229     19       35       4       3
# 1                70        0   282    497       51       4      10
# 2               337        0   176    319       46       0       4
# 3               310        0    10    506        4       0       9
# 4               169        0  1390    246      105       6       3
# ...             ...      ...   ...    ...      ...     ...     ...
# 3948            500        1   906    171       51       4      10
# 3949            300        1   876    569        4       0       9
# 3950            427        0   326    111       72       0       9
# 3951             60        0  1031    184      105       6      10
# 3952            437        1   931    384       49       3       5
#
#       Product ID  Category  Sub-Category  Product Name  Order Priority
# 0           2160         1            14            79               1
# 1            462         1             2           271               3
# 2            923         1             6           739               1
# 3            826         1             3            27               1
# 4            352         1             2           697               3
# ...          ...       ...           ...           ...             ...
# 3948        1064         1             6           149               3
# 3949         822         1             3           333               3
# 3950         807         1             3           334               3
# 3951         949         1             6             1               1
# 3952        2004         1             2          1116               3
#
# [3953 rows x 20 columns]

# %%
df_final.rename(columns={0:"Sales",1:"Quantity",2:"Discount",3:"Profit",4:"Shipping Cost"},inplace=True)

# %%
df_final.head()
# Out:
#       Sales  Quantity  Discount    Profit  Shipping Cost  Order ID  Ship Mode  \
# 0  0.134822       0.0       0.0  0.035948            1.0      1476          0
# 1  0.985939       0.0       0.0  0.129085            1.0      1359          3
# 2  0.334160       0.5       0.0  0.247549            1.0      1773          3
# 3  0.238007       0.5       0.2  0.258578            1.0      1758          0
# 4  0.721257       0.0       0.0  0.620588            1.0       353          3
#
#    Customer ID  Customer Name  Segment  City  State  Country  Market  Region  \
# 0          706            447        1  1229     19       35       4       3
# 1          183             70        0   282    497       51       4      10
# 2          544            337        0   176    319       46       0       4
# 3          468            310        0    10    506        4       0       9
# 4          232            169        0  1390    246      105       6       3
#
#    Product ID  Category  Sub-Category  Product Name  Order Priority
# 0        2160         1            14            79               1
# 1         462         1             2           271               3
# 2         923         1             6           739               1
# 3         826         1             3            27               1
# 4         352         1             2           697               3

# %%
df_final.isnull().sum()
# Out:
# Sales             0
# Quantity          0
# Discount          0
# Profit            0
# Shipping Cost     0
# Order ID          0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# City              0
# State             0
# Country           0
# Market            0
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Order Priority    0
# dtype: int64

# %%
#Modeling

# %%
from sklearn.tree import DecisionTreeRegressor #DecisionTreeClassifier
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor#RandomForestClassifier

# %%
Linreg=LinearRegression()

# %%
Y=df_final["Sales"]

# %%
X=df_final.drop(["Sales"],axis=1)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=1)

# %%
lm=Linreg.fit(X_train,y_train)

# %%
Linreg.score(X_train,y_train)
# Out:
# 0.46350710020880503

# %%
#dtr=DecisionTreeRegressor(criterion="gini")

# %%
dtr=DecisionTreeRegressor(criterion="mse")

# %%
dtr = DecisionTreeRegressor(criterion='squared_error')

# %%
dt1 = dtr.fit(X_train, y_train)

# %%
dt1
# Out:
# DecisionTreeRegressor()

# %%
rf=RandomForestRegressor(n_estimators=100,random_state=50)

# %%
rf1=rf.fit(X_train,y_train)

# %%
rf.score(X_train,y_train)
# Out:
# 0.9356208161053988

# %%
y_pre_rf = rf.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
mean_squared_error(y_test,y_pre_rf)
# Out:
# 0.03031141231204717

# %%
mean_absolute_error(y_test,y_pre_rf)
# Out:
# 0.13724533673577083

# %%
from math import sqrt

# %%
sqrt(mean_squared_error(y_test,y_pre_rf))
# Out:
# 0.17410172977902078

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
gb_r = GradientBoostingRegressor(n_estimators=600)

# %%
import xgboost as xg

# %%
# !pip install xgboost

# %%
xgb_r = xg.XGBRegressor(n_estimators = 10)

# %%
gbr_model=gb_r.fit(X_train,y_train)

# %%
xgb_model=xgb_r.fit(X_train,y_train)

# %%
gb_r.score(X_train,y_train)

# %%
xgb_r.score(X_train,y_train)

# %%
from sklearn.ensemble import AdaBoostRegressor

# %%
ab_r=AdaBoostRegressor(n_estimators=100)

# %%
abr_model=ab_r.fit(X_train,y_train)

# %%
ab_r.score(X_train,y_train)
